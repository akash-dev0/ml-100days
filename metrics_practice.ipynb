# %% [markdown]
# <a href="https://colab.research.google.com/github/akash-dev0/ml-100days/blob/master/metrics_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import mean_squared_error, mean_absolute_error, root_mean_squared_error, r2_score

# %%
y_actual = [100, 200, 300, 400, 500]
y_pred = [100, 190, 310, 380, 520]

# %%
MAE = (mean_absolute_error(y_actual, y_pred))
print("MAE: ", MAE)
# Out:
# MAE:  12.0

# %%
MSE = (mean_squared_error(y_actual, y_pred))
print("MSE: ", MSE)
# Out:
# MSE:  200.0

# %%
RMSE = (root_mean_squared_error(y_actual, y_pred))
print("RMSE: ", RMSE)
# Out:
# RMSE:  14.142135623730951

# %%
RMSE2 = (np.sqrt(mean_squared_error(y_actual, y_pred)))
print("RMSE2: ", RMSE2)
# Out:
# RMSE2:  14.142135623730951

# %%
R2 = r2_score(y_actual, y_pred)
print("R2: ", R2)
# Out:
# R2:  0.99

# %%
n = 5
k = 2
adj_r2 = 1 - ((1-R2))*(n-1)/(n-k-1)
print("Adjusted_R2: ", adj_r2)
# Out:
# Adjusted_R2:  0.98
